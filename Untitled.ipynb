# %%
import numpy as np
import pandas as pd

# %%
codes = pd.read_csv('UBPR_Complete_User_Guide_2017-06-22.csv')
codes.head()
# Out:
#                                 SECTION SECTION NUMBER  \
# 0  Analysis of Concentrations of Credit             7B
# 1  Analysis of Concentrations of Credit             7B
# 2  Analysis of Concentrations of Credit             7B
# 3  Analysis of Concentrations of Credit             7B
# 4  Analysis of Concentrations of Credit             7B
#
#                        SUBSECTION CONCEPT ID CONCEPT NAME  \
# 0               Real Estate Loans     7B.1.1     UBPRE884
# 1      Construction & Development     7B.2.1     UBPRD490
# 2         1-4 Family Construction     7B.3.1     UBPRE632
# 3  Other Const & Land Development     7B.4.1     UBPRE657
# 4             Secured by Farmland     7B.5.1     UBPRE880
#
#                                          DESCRIPTION  \
# 0             Total Real Estate Loans, % Tot Capital
# 1    Construction & Development Loans, % Tot Capital
# 2       1-4 Family Construction Loans, % Tot Capital
# 3  Other Const & Land Development Loans, % Tot Ca...
# ...

# %%
ref = pd.read_csv('UBPR_Complete_User_Guide_2017-06-22_reference.csv')
ref.head()
# Out:
#                     REFERENCING SECTION REFERENCING SECTION NUMBER  \
# 0  Analysis of Concentrations of Credit                         7B
# 1  Analysis of Concentrations of Credit                         7B
# 2  Analysis of Concentrations of Credit                         7B
# 3  Analysis of Concentrations of Credit                         7B
# 4  Analysis of Concentrations of Credit                         7B
#
#   REFERENCED CONCEPT                                        DESCRIPTION  \
# 0           UBPR1410                                  Real Estate Loans
# 1           UBPR1415            CONSTRUCTION AND LAND DEVELOPMENT LOANS
# 2           UBPR1480  Real Estate Loans Secured by Nonfarm Nonreside...
# 3           UBPR1563                                        Other Loans
# 4           UBPR1590                                 Agricultural Loans
#
#                                            NARRATIVE  \
# 0                Total loans secured by real estate.
# ...

# %%
ref.loc[ref['REFERENCED CONCEPT'].isin(codes['CONCEPT NAME']),:]
# Out:
#                             REFERENCING SECTION REFERENCING SECTION NUMBER  \
# 0          Analysis of Concentrations of Credit                         7B
# 4          Analysis of Concentrations of Credit                         7B
# 12         Analysis of Concentrations of Credit                         7B
# 14         Analysis of Concentrations of Credit                         7B
# 16         Analysis of Concentrations of Credit                         7B
# 17         Analysis of Concentrations of Credit                         7B
# 19         Analysis of Concentrations of Credit                         7B
# 42         Analysis of Concentrations of Credit                         7B
# 44         Analysis of Concentrations of Credit                         7B
# 56    Analysis of Credit Allowance and Loan Mix                          7
# 59    Analysis of Credit Allowance and Loan Mix                          7
# ...

# %%
pd.Series.isin()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-8723ff65ecb8> in <module>()
# ----> 1 pd.Series.isin()
#
# TypeError: isin() missing 2 required positional arguments: 'self' and 'values'
